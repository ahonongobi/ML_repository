# %%
import matplotlib.pyplot as plt

# Data
throughput_values = [250, 221, 90, 436, 248, 1780, 504, 628, 684, 531, 177203]
latency_values = [32225, 20099, 220000000, 18828, 2566, 13556, 194000000, 2378, 566000000, 767000000, 71000]

# Plot
plt.figure(figsize=(10, 6))
plt.scatter(throughput_values, latency_values, marker='o', color='blue')

# Add labels and title
plt.xlabel('Throughput (M/sec)')
plt.ylabel('Latency (μs)')
plt.title('XFS File System Performance')

# Show plot
plt.grid(True)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Data
throughput_values = [250, 221, 90, 436, 248, 1780, 504, 628, 684, 531, 177203]
latency_values = [32225, 20099, 220000000, 18828, 2566, 13556, 194000000, 2378, 566000000, 767000000, 71000]

# Plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x=throughput_values, y=latency_values, color='blue', marker='o')

# Add labels and title
plt.xlabel('Throughput (M/sec)')
plt.ylabel('Latency (μs)')
plt.title('XFS File System Performance')

# Show plot
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Throughput data points
throughput = {
    "Sequential Output": [250, 221, 90, 436, 248],
    "Sequential Input": [628],
    "Sequential Create": [504]
}

# Latency data points in microseconds
latency = {
    "Sequential Output": [32225, 20099, 220000, 18828, 2566],
    "Sequential Input": [194000],
    "Sequential Create": [504000]
}

# Plotting throughput vs. latency
plt.figure(figsize=(8, 6))
for key in throughput.keys():
    plt.scatter(throughput[key], latency[key], label=key)

plt.xlabel("Throughput (M/sec)")
plt.ylabel("Latency (microseconds)")
plt.title("Bonnie++ Benchmark Results")
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Données de throughput et de latence pour chaque type de système de fichiers
throughput = [250, 221, 90, 436, 248, 1780, 628, 124536, 684, 531, 177203, 504]
latency = [32225, 20099, 220000, 18828, 2566, 13556, 194000, 2378, 566000, 767000, 71000, 776000]


# Étiquettes pour les types de système de fichiers
filesystems = ['Seq. Out - Per Char', 'Seq. Out - Block', 'Seq. Out - Rewrite',
               'Seq. In - Per Char', 'Seq. In - Block', 'Random Seeks - Create',
               'Random Seeks - Read', 'Random Seeks - Delete',
               'Seq. Create - Create', 'Seq. Create - Read', 'Seq. Create - Delete',
               'Random Create - Create']

# Création du scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(throughput, latency, marker='o', color='blue')

# Ajout des étiquettes pour chaque point
for i, txt in enumerate(filesystems):
    plt.annotate(txt, (throughput[i], latency[i]), fontsize=8)

# Ajout des titres et des labels
plt.title('Scatter Plot de Throughput vs. Latency pour différents types de systèmes de fichiers')
plt.xlabel('Throughput (M/sec or /sec)')
plt.ylabel('Latency (µs or ms)')

# Afficher le scatter plot
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Données de latence et de débit pour le fichier 1G
latency_1G = [1148, 172, 90, 608, 55, 1157, 137, 96, 630, 56, 1119, 145, 130, 599, 59, 2820, 231, 91, 612, 57, 1144, 133, 114, 638, 60]
throughput_1G = [259, 48, 27, 441, 95, 253, 49, 27, 434, 92, 249, 47, 28, 439, 94, 248, 49, 28, 430, 93, 249, 49, 28, 429, 91]

# Données de latence et de débit pour le fichier 128M
throughput_128M = [249, 43, 25, 435, 94, 247, 42, 25, 430, 91, 249, 42, 25, 436, 94, 248, 43, 25, 425, 90, 249, 43, 25, 432, 91]
latency_128M = [1486, 157, 92, 618, 61, 1486, 157, 92, 618, 61, 1448, 149, 86, 610, 51, 1443, 150, 82, 627, 53, 1436, 151, 85, 617, 51]

# Création du scatter plot pour le fichier 16M
throughput_16M = [29,0,157,92,29]
latency_16M = [98,24,217,92,106]

# Création du scatter plot pour le fichier 1M
throughput_1M = [158,0,0,158,0]
latency_1M = [1684,53,24,1639,58]
# Création du scatter plot pour le fichier 2G
throughput_2G = [156,34,101,101,34]
latency_2G = [1797,7549,58,53,2467]
# creation du scatter plot pour 256M
throughput_256M = [156, 29 , 31 , 484 , 104]
latency_256M = [1805,85,96,546,55]
# creation du scatter plot pour 256M
throughput_2M = [156, 0 ,0, 493,0]
latency_2M = [1770,61,52,595,27]
# Création du scatter plot pour le fichier 1G
plt.figure(figsize=(10, 6))
plt.scatter(throughput_1G, latency_1G, color='blue', alpha=0.5, label='File Size 1G')
plt.scatter(throughput_128M, latency_128M, color='red', alpha=0.5, label='File Size 128M')
plt.scatter(throughput_16M,latency_16M, color='green', alpha=0.5, label='File Size 16M' )
plt.scatter(throughput_1M,latency_1M, color='yellow', alpha=0.5, label='File Size 1M' )
plt.scatter(throughput_2G,latency_2G, color='indigo', alpha=0.5, label='File Size 2G' )
plt.scatter(throughput_256M,latency_256M, color='yellow', alpha=0.5, label='File Size 256M' )
plt.scatter(throughput_2M,latency_2M, color='pink', alpha=0.5, label='File Size 2M' )



# Ajout de la légende
plt.legend()

# Ajout de titres et d'étiquettes
plt.title('Scatter Plot : Throughput vs. Latency _XFS File System')
plt.xlabel('Throughput (M/sec)')
plt.ylabel('Latency (µs)')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Throughput data
throughput = {
    "Per Char": 250,
    "Block": 221,
    "Rewrite": 90,
    "Sequential Input (Per Char)": 436,
    "Sequential Input (Block)": 248,
    "Random Seeks": 1780,
    "Sequential Create": 628,
    "Random Create": 531
}

# Latency data in microseconds
latency_us = {
    "Per Char": 32225,
    "Block": 20099,
    "Rewrite": 220000,  # Convert milliseconds to microseconds
    "Sequential Input (Per Char)": 18828,
    "Sequential Input (Block)": 2566,
    "Random Seeks": 13556,
    "Sequential Create": 194000,  # Convert milliseconds to microseconds
    "Random Create": 767000  # Convert milliseconds to microseconds
}

# Convert latency from microseconds to milliseconds
latency_ms = {op: lat / 1000 for op, lat in latency_us.items()}

# Create scatter plot
plt.figure(figsize=(10, 6))

for op, thr in throughput.items():
    lat = latency_ms[op]
    plt.scatter(thr, lat, label=op)

plt.title('Scatter Plot of Throughput vs Latency (ext4)')
plt.xlabel('Throughput (M/sec or files/s)')
plt.ylabel('Latency (ms)')
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt

# Throughput data
throughput = {
    "Sequential Output (Per Char)": 151,
    "Sequential Output (Block)": 216,
    "Sequential Output (Rewrite)": 89,
    "Sequential Input (Per Char)": 469,
    "Sequential Input (Block)": 251,
    "Random Seeks": 1881,
    "Sequential Create": 449,
    "Random Create": 436
}

# Latency data in microseconds
latency_us = {
    "Sequential Output (Per Char)": 54345,
    "Sequential Output (Block)": 44342,
    "Sequential Output (Rewrite)": 199000,  # Convert milliseconds to microseconds
    "Sequential Input (Per Char)": 17611,
    "Sequential Input (Block)": 796,
    "Random Seeks": 20005,
    "Sequential Create": 196000,  # Convert milliseconds to microseconds
    "Random Create": 201000  # Convert milliseconds to microseconds
}

# Convert latency from microseconds to milliseconds
latency_ms = {op: lat / 1000 for op, lat in latency_us.items()}

# Create scatter plot
plt.figure(figsize=(10, 6))

for op, thr in throughput.items():
    lat = latency_ms[op]
    plt.scatter(thr, lat, label=op)

plt.title('Scatter Plot of Throughput vs Latency (XFS)')
plt.xlabel('Throughput (M/sec or files/s)')
plt.ylabel('Latency (ms)')
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt

# Throughput data for ext4
ext4_throughput = {
    "Per Char": 250,
    "Block": 221,
    "Rewrite": 90,
    "Sequential Input (Per Char)": 436,
    "Sequential Input (Block)": 248,
    "Random Seeks": 1780,
    "Sequential Create": 628,
    "Random Create": 531
}

# Latency data for ext4 in microseconds
ext4_latency_us = {
    "Per Char": 32225,
    "Block": 20099,
    "Rewrite": 220000,  # Convert milliseconds to microseconds
    "Sequential Input (Per Char)": 18828,
    "Sequential Input (Block)": 2566,
    "Random Seeks": 13556,
    "Sequential Create": 194000,  # Convert milliseconds to microseconds
    "Random Create": 767000  # Convert milliseconds to microseconds
}

# Throughput data for XFS
xfs_throughput = {
    "Sequential Output (Per Char)": 151,
    "Sequential Output (Block)": 216,
    "Sequential Output (Rewrite)": 89,
    "Sequential Input (Per Char)": 469,
    "Sequential Input (Block)": 251,
    "Random Seeks": 1881,
    "Sequential Create": 449,
    "Random Create": 436
}

# Latency data for XFS in microseconds
xfs_latency_us = {
    "Sequential Output (Per Char)": 54345,
    "Sequential Output (Block)": 44342,
    "Sequential Output (Rewrite)": 199000,  # Convert milliseconds to microseconds
    "Sequential Input (Per Char)": 17611,
    "Sequential Input (Block)": 796,
    "Random Seeks": 20005,
    "Sequential Create": 196000,  # Convert milliseconds to microseconds
    "Random Create": 201000  # Convert milliseconds to microseconds
}

# Convert latency from microseconds to milliseconds
ext4_latency_ms = {op: lat / 1000 for op, lat in ext4_latency_us.items()}
xfs_latency_ms = {op: lat / 1000 for op, lat in xfs_latency_us.items()}

# Create scatter plot
plt.figure(figsize=(10, 6))

# Plot ext4 data and do not reapet the legend
for op, thr in ext4_throughput.items():
    lat = ext4_latency_ms[op]
    plt.scatter(thr, lat, color='blue', label='ext4' if op == 'Per Char' else None)

# Plot XFS data and do not reapet the legend
for op, thr in xfs_throughput.items():
    lat = xfs_latency_ms[op]
    plt.scatter(thr, lat, color='red', label='XFS' if op == 'Sequential Output (Per Char)' else None)

plt.title('Scatter Plot of Throughput vs Latency (ext4 vs XFS)')
plt.xlabel('Throughput (M/sec or files/s)')
plt.ylabel('Latency (ms)')
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt

# Throughput data for ext4
ext4_throughput = {
    "Per Char": 250,
    "Block": 221,
    "Rewrite": 90,
    "Sequential Input (Per Char)": 436,
    "Sequential Input (Block)": 248,
    "Random Seeks": 1780,
    "Sequential Create": 628,
    "Random Create": 531
}

# Latency data for ext4 in microseconds
ext4_latency_us = {
    "Per Char": 32225,
    "Block": 20099,
    "Rewrite": 220000,  # Convert milliseconds to microseconds
    "Sequential Input (Per Char)": 18828,
    "Sequential Input (Block)": 2566,
    "Random Seeks": 13556,
    "Sequential Create": 194000,  # Convert milliseconds to microseconds
    "Random Create": 767000  # Convert milliseconds to microseconds
}

# Throughput data for XFS
xfs_throughput = {
    "Sequential Output (Per Char)": 151,
    "Sequential Output (Block)": 216,
    "Sequential Output (Rewrite)": 89,
    "Sequential Input (Per Char)": 469,
    "Sequential Input (Block)": 251,
    "Random Seeks": 1881,
    "Sequential Create": 449,
    "Random Create": 436
}

# Latency data for XFS in microseconds
xfs_latency_us = {
    "Sequential Output (Per Char)": 54345,
    "Sequential Output (Block)": 44342,
    "Sequential Output (Rewrite)": 199000,  # Convert milliseconds to microseconds
    "Sequential Input (Per Char)": 17611,
    "Sequential Input (Block)": 796,
    "Random Seeks": 20005,
    "Sequential Create": 196000,  # Convert milliseconds to microseconds
    "Random Create": 201000  # Convert milliseconds to microseconds
}

# Convert latency from microseconds to milliseconds
ext4_latency_ms = {op: lat / 1000 for op, lat in ext4_latency_us.items()}
xfs_latency_ms = {op: lat / 1000 for op, lat in xfs_latency_us.items()}

# Create subplots
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

# Plot for ext4
for op, thr in ext4_throughput.items():
    lat = ext4_latency_ms[op]
    axs[0].scatter(thr, lat, color='blue', label='ext4' if op == 'Per Char' else None)

axs[0].set_title('ext4')
axs[0].set_xlabel('Throughput (M/sec or files/s)')
axs[0].set_ylabel('Latency (ms)')
axs[0].grid(True)

# Plot for XFS
for op, thr in xfs_throughput.items():
    lat = xfs_latency_ms[op]
    axs[1].scatter(thr, lat, color='red', label='XFS' if op == 'Sequential Output (Per Char)' else None)

axs[1].set_title('XFS')
axs[1].set_xlabel('Throughput (M/sec or files/s)')
axs[1].set_ylabel('Latency (ms)')
axs[1].grid(True)

# Plot for both
for op, thr in ext4_throughput.items():
    lat = ext4_latency_ms[op]
    axs[2].scatter(thr, lat, color='blue', label='ext4' if op == 'Per Char' else None)

for op, thr in xfs_throughput.items():
    lat = xfs_latency_ms[op]
    axs[2].scatter(thr, lat, color='red', label='XFS' if op == 'Sequential Output (Per Char)' else None)

axs[2].set_title('ext4 and XFS')
axs[2].set_xlabel('Throughput (M/sec or files/s)')
axs[2].set_ylabel('Latency (ms)')
axs[2].grid(True)
axs[2].legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the operations to compare
operations = [
    "Per Char",
    "Block",
    "Rewrite",
    "Sequential Input (Per Char)",
    "Sequential Input (Block)",
    "Random Seeks",
    "Sequential Create",
    "Random Create"
]

# Throughput data for ext4
ext4_throughput = {
    "Per Char": 250,
    "Block": 221,
    "Rewrite": 90,
    "Sequential Input (Per Char)": 436,
    "Sequential Input (Block)": 248,
    "Random Seeks": 1780,
    "Sequential Create": 628,
    "Random Create": 531
}

# Throughput data for XFS
xfs_throughput = {
    "Per Char": 151,
    "Block": 216,
    "Rewrite": 89,
    "Sequential Input (Per Char)": 469,
    "Sequential Input (Block)": 251,
    "Random Seeks": 1881,
    "Sequential Create": 449,
    "Random Create": 436
}

# Set up the figure and axis
fig, ax = plt.subplots(figsize=(10, 6))

# Set the width of the bars
bar_width = 0.35

# Set the positions for the bars
ext4_positions = np.arange(len(operations))
xfs_positions = [pos + bar_width for pos in ext4_positions]

# Plot the ext4 bars
ext4_bars = ax.bar(ext4_positions, ext4_throughput.values(), bar_width, label='ext4')

# Plot the XFS bars
xfs_bars = ax.bar(xfs_positions, xfs_throughput.values(), bar_width, label='XFS')

# Add labels, title, and legend
ax.set_xlabel('Operations')
ax.set_ylabel('Throughput (M/sec)')
ax.set_title('Throughput Comparison Between ext4 and XFS')
ax.set_xticks([pos + bar_width / 2 for pos in ext4_positions])
ax.set_xticklabels(operations, rotation=45, ha='right')
ax.legend()

# Show plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the operations to compare
operations = [
    "Per Char",
    "Block",
    "Rewrite",
    "Sequential Input (Per Char)",
    "Sequential Input (Block)",
    "Random Seeks",
    "Sequential Create",
    "Random Create"
]

# Latency data for ext4 in milliseconds
ext4_latency = {
    "Per Char": 32225,
    "Block": 20099,
    "Rewrite": 220000,  # Converted milliseconds to microseconds
    "Sequential Input (Per Char)": 18828,
    "Sequential Input (Block)": 2566,
    "Random Seeks": 13556,
    "Sequential Create": 194000,  # Converted milliseconds to microseconds
    "Random Create": 767000  # Converted milliseconds to microseconds
}

# Latency data for XFS in milliseconds
xfs_latency = {
    "Per Char": 54345,
    "Block": 44342,
    "Rewrite": 199000,  # Converted milliseconds to microseconds
    "Sequential Input (Per Char)": 17611,
    "Sequential Input (Block)": 796,
    "Random Seeks": 20005,
    "Sequential Create": 196000,  # Converted milliseconds to microseconds
    "Random Create": 201000  # Converted milliseconds to microseconds
}

# Set up the figure and axis
fig, ax = plt.subplots(figsize=(10, 6))

# Set the width of the bars
bar_width = 0.35

# Set the positions for the bars
ext4_positions = np.arange(len(operations))
xfs_positions = [pos + bar_width for pos in ext4_positions]

# Plot the ext4 bars
ext4_bars = ax.bar(ext4_positions, ext4_latency.values(), bar_width, label='ext4')

# Plot the XFS bars
xfs_bars = ax.bar(xfs_positions, xfs_latency.values(), bar_width, label='XFS')

# Add labels, title, and legend
ax.set_xlabel('Operations')
ax.set_ylabel('Latency (ms)')
ax.set_title('Latency Comparison Between ext4 and XFS')
ax.set_xticks([pos + bar_width / 2 for pos in ext4_positions])
ax.set_xticklabels(operations, rotation=45, ha='right')
ax.legend()

# Show plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the operations to compare
operations = [
    "Per Char",
    "Block",
    "Rewrite",
    "Sequential Input (Per Char)",
    "Sequential Input (Block)",
    "Random Seeks",
    "Sequential Create",
    "Random Create"
]

# Latency data for ext4 in microseconds in /mnt
ext4_latency_mnt = {
    "Per Char": 32225,
    "Block": 20099,
    "Rewrite": 220000,
    "Sequential Input (Per Char)": 18828,
    "Sequential Input (Block)": 2566,
    "Random Seeks": 13556,
    "Sequential Create": 194000,
    "Random Create": 767000
}

# Latency data for XFS in microseconds in /mnt
xfs_latency_mnt = {
    "Per Char": 54345,
    "Block": 44342,
    "Rewrite": 199000,
    "Sequential Input (Per Char)": 17611,
    "Sequential Input (Block)": 796,
    "Random Seeks": 20005,
    "Sequential Create": 196000,
    "Random Create": 201000
}

# Latency data for ext4 in microseconds in /shm
ext4_latency_shm = {
    "Per Char": 51865,
    "Block": 34174,
    "Rewrite": 205000,
    "Sequential Input (Per Char)": 17046,
    "Sequential Input (Block)": 1049,
    "Random Seeks": 27760,
    "Sequential Create": 545000,
    "Random Create": 192000
}

# Latency data for XFS in microseconds in /shm
xfs_latency_shm = {
    "Per Char": 32883,
    "Block": 91035,
    "Rewrite": 225000,
    "Sequential Input (Per Char)": 19006,
    "Sequential Input (Block)": 1720,
    "Random Seeks": 117000,
    "Sequential Create": 264000,
    "Random Create": 29618
}

# Set up the figure and axis for the first graph
fig, ax = plt.subplots(figsize=(10, 6))

# Set the width of the bars
bar_width = 0.35

# Set the positions for the bars
bar_positions = np.arange(len(operations))

# Plot Ext4 latency comparison between /mnt and /dev/shm
ext4_mnt_bars = ax.bar(bar_positions - bar_width/2, list(ext4_latency_mnt.values()), bar_width, label='Ext4 - /mnt')
ext4_shm_bars = ax.bar(bar_positions + bar_width/2, list(ext4_latency_shm.values()), bar_width, label='Ext4 - /dev/shm')

# Set labels and title
ax.set_xticks(bar_positions)
ax.set_xticklabels(operations, rotation=45, ha='right')
ax.set_ylabel('Latency (microseconds)')
ax.set_title('Latency Comparison Between Ext4 on /mnt and /dev/shm')
ax.legend()

# Show the plot
plt.tight_layout()
plt.show()

# Set up the figure and axis for the second graph
fig, ax = plt.subplots(figsize=(10, 6))

# Plot XFS latency comparison between /mnt and /dev/shm
xfs_mnt_bars = ax.bar(bar_positions - bar_width/2, list(xfs_latency_mnt.values()), bar_width, label='XFS - /mnt')
xfs_shm_bars = ax.bar(bar_positions + bar_width/2, list(xfs_latency_shm.values()), bar_width, label='XFS - /dev/shm')

# Set labels and title
ax.set_xticks(bar_positions)
ax.set_xticklabels(operations, rotation=45, ha='right')
ax.set_ylabel('Latency (microseconds)')
ax.set_title('Latency Comparison Between XFS on /mnt and /dev/shm')
ax.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt
import community  # Install using: pip install python-louvain

# Création du graphe
G = nx.Graph()

# Ajout des nœuds (individus)
G.add_nodes_from(["Alice", "Gobi", "Charlie", "Kelvine", "Eve"])

# Ajout des affiliations (arêtes)
G.add_edge("Alice", "Group1")
G.add_edge("Alice", "Group2")
G.add_edge("Gobi", "Group1")
G.add_edge("Charlie", "Group2")
G.add_edge("Kelvine", "Group1")
G.add_edge("Eve", "Group2")

# Dessin du graphe (optionnel)
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_color='lightblue', node_size=1500)
plt.title("Graphe d'affiliation")
plt.show()

# Détection des communautés
partition = community.best_partition(G)

# Affichage des communautés
print("Communautés détectées:")
for node, community_id in partition.items():
    print(f"{node} -> Communauté {community_id}")
# Out:
# Communautés détectées:
# Alice -> Communauté 0
# Gobi -> Communauté 0
# Charlie -> Communauté 1
# Kelvine -> Communauté 0
# Eve -> Communauté 1
# Group1 -> Communauté 0
# Group2 -> Communauté 1

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the operations to compare
operations = [
    "Per Char",
    "Block",
    "Rewrite",
    "Sequential Input (Per Char)",
    "Sequential Input (Block)",
    "Random Seeks",
    "Sequential Create",
    "Random Create"
]

# Latency data for ext4 in microseconds in /mnt
ext4_latency_mnt = np.array([
    32225, 20099, 220000, 18828, 2566, 13556, 194000, 767000
]).reshape(1, -1)

# Latency data for XFS in microseconds in /mnt
xfs_latency_mnt = np.array([
    54345, 44342, 199000, 17611, 796, 20005, 196000, 201000
]).reshape(1, -1)

# Latency data for ext4 in microseconds in /shm
ext4_latency_shm = np.array([
    51865, 34174, 205000, 17046, 1049, 27760, 545000, 192000
]).reshape(1, -1)

# Latency data for XFS in microseconds in /shm
xfs_latency_shm = np.array([
    32883, 91035, 225000, 19006, 1720, 117000, 264000, 29618
]).reshape(1, -1)

# Combine all data
data = np.vstack((ext4_latency_mnt, xfs_latency_mnt, ext4_latency_shm, xfs_latency_shm))

# Set up the figure and axis
fig, ax = plt.subplots(figsize=(12, 6))

# Create the heatmap
heatmap = ax.imshow(data, cmap='viridis')

# Add colorbar
cbar = fig.colorbar(heatmap)

# Set labels and title
ax.set_xticks(np.arange(len(operations)))
ax.set_yticks(np.arange(4))
ax.set_xticklabels(operations, rotation=45, ha='right')
ax.set_yticklabels(['Ext4 - /mnt', 'XFS - /mnt', 'Ext4 - /dev/shm', 'XFS - /dev/shm'])
ax.set_xlabel('Operations')
ax.set_ylabel('File Systems')
ax.set_title('Latency Comparison Between File Systems and Mount Points')

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the operations to compare
operations = [
    "Per Char",
    "Block",
    "Rewrite",
    "Sequential Input (Per Char)",
    "Sequential Input (Block)",
    "Random Seeks",
    "Sequential Create",
    "Random Create"
]

# Latency data for ext4 in microseconds in /mnt
ext4_latency_mnt = [
    32225,
    20099,
    220000,
    18828,
    2566,
    13556,
    194000,
    767000
]

# Latency data for XFS in microseconds in /mnt
xfs_latency_mnt = [
    54345,
    44342,
    199000,
    17611,
    796,
    20005,
    196000,
    201000
]

# Latency data for ext4 in microseconds in /shm
ext4_latency_shm = [
    51865,
    34174,
    205000,
    17046,
    1049,
    27760,
    545000,
    192000
]

# Latency data for XFS in microseconds in /shm
xfs_latency_shm = [
    32883,
    91035,
    225000,
    19006,
    1720,
    117000,
    264000,
    29618
]

# Set up the figure and axis for the box plot
fig, ax = plt.subplots(figsize=(10, 6))

# Combine latency data for both file systems
data = [ext4_latency_mnt, xfs_latency_mnt, ext4_latency_shm, xfs_latency_shm]

# Create box plots
box = ax.boxplot(data, patch_artist=True)

# Add labels and title
ax.set_xticklabels(['Ext4 /mnt', 'XFS /mnt', 'Ext4 /dev/shm', 'XFS /dev/shm'], rotation=45, ha='right')
ax.set_ylabel('Latency (microseconds)')
ax.set_title('Latency Comparison Between File Systems')

# Customizing colors
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']
for patch, color in zip(box['boxes'], colors):
    patch.set_facecolor(color)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Define the operations to compare
operations = [
    "Per Char",
    "Block",
    "Rewrite",
    "Sequential Input (Per Char)",
    "Sequential Input (Block)",
    "Random Seeks",
    "Sequential Create",
    "Random Create"
]

# Latency data for ext4 in microseconds in /mnt
ext4_latency_mnt = {
    "Per Char": 32225,
    "Block": 20099,
    "Rewrite": 220000,
    "Sequential Input (Per Char)": 18828,
    "Sequential Input (Block)": 2566,
    "Random Seeks": 13556,
    "Sequential Create": 194000,
    "Random Create": 767000
}

# Latency data for XFS in microseconds in /mnt
xfs_latency_mnt = {
    "Per Char": 54345,
    "Block": 44342,
    "Rewrite": 199000,
    "Sequential Input (Per Char)": 17611,
    "Sequential Input (Block)": 796,
    "Random Seeks": 20005,
    "Sequential Create": 196000,
    "Random Create": 201000
}

# Set up the figure and axis
fig, ax = plt.subplots(figsize=(10, 6))

# Plot Ext4 latency comparison between /mnt and /dev/shm
for fs, latency_data in [("Ext4 - /mnt", ext4_latency_mnt), ("XFS - /mnt", xfs_latency_mnt)]:
    latencies = [latency_data[op] for op in operations]
    ax.plot(operations, latencies, marker='o', label=fs)

# Set labels and title
ax.set_ylabel('Latency (microseconds)')
ax.set_title('Latency Comparison Between Ext4 and XFS on /mnt')
ax.legend()

# Rotate x-axis labels for better visibility
plt.xticks(rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Define the operations to compare
operations = [
    "Per Char",
    "Block",
    "Rewrite",
    "Sequential Input (Per Char)",
    "Sequential Input (Block)",
    "Random Seeks",
    "Sequential Create",
    "Random Create"
]

# Latency data for ext4 in microseconds in /mnt
ext4_latency_mnt = {
    "Per Char": 32225,
    "Block": 20099,
    "Rewrite": 220000,
    "Sequential Input (Per Char)": 18828,
    "Sequential Input (Block)": 2566,
    "Random Seeks": 13556,
    "Sequential Create": 194000,
    "Random Create": 767000
}

# Latency data for XFS in microseconds in /mnt
xfs_latency_mnt = {
    "Per Char": 54345,
    "Block": 44342,
    "Rewrite": 199000,
    "Sequential Input (Per Char)": 17611,
    "Sequential Input (Block)": 796,
    "Random Seeks": 20005,
    "Sequential Create": 196000,
    "Random Create": 201000
}

# Latency data for ext4 in microseconds in /shm
ext4_latency_shm = {
    "Per Char": 51865,
    "Block": 34174,
    "Rewrite": 205000,
    "Sequential Input (Per Char)": 17046,
    "Sequential Input (Block)": 1049,
    "Random Seeks": 27760,
    "Sequential Create": 545000,
    "Random Create": 192000
}

# Latency data for XFS in microseconds in /shm
xfs_latency_shm = {
    "Per Char": 32883,
    "Block": 91035,
    "Rewrite": 225000,
    "Sequential Input (Per Char)": 19006,
    "Sequential Input (Block)": 1720,
    "Random Seeks": 117000,
    "Sequential Create": 264000,
    "Random Create": 29618
}

# Set up the figure and axis
fig, axs = plt.subplots(2, 1, figsize=(10, 12), sharex=True)

# Plot Ext4 latency comparison between /mnt and /dev/shm
for ax, fs_latency_mnt, fs_latency_shm, fs_name in zip(axs, [ext4_latency_mnt, xfs_latency_mnt], [ext4_latency_shm, xfs_latency_shm], ['Ext4', 'XFS']):
    latencies_mnt = [fs_latency_mnt[op] for op in operations]
    latencies_shm = [fs_latency_shm[op] for op in operations]
    ax.plot(operations, latencies_mnt, marker='o', label=f'{fs_name} - /mnt')
    ax.plot(operations, latencies_shm, marker='o', label=f'{fs_name} - /dev/shm')

    # Set labels and title for each subplot
    ax.set_ylabel('Latency (microseconds)')
    ax.set_title(f'Latency Comparison Between {fs_name} on /mnt and /dev/shm')
    ax.legend()

# Rotate x-axis labels for better visibility
plt.xticks(rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Define the operations to compare
operations = [
    "Per Char",
    "Block",
    "Rewrite",
    "Sequential Input (Per Char)",
    "Sequential Input (Block)",
    "Random Seeks",
    "Sequential Create",
    "Random Create"
]

# Latency data for ext4 in microseconds in /mnt
ext4_latency_mnt = {
    "Per Char": 32225,
    "Block": 20099,
    "Rewrite": 220000,
    "Sequential Input (Per Char)": 18828,
    "Sequential Input (Block)": 2566,
    "Random Seeks": 13556,
    "Sequential Create": 194000,
    "Random Create": 767000
}

# Latency data for XFS in microseconds in /mnt
xfs_latency_mnt = {
    "Per Char": 54345,
    "Block": 44342,
    "Rewrite": 199000,
    "Sequential Input (Per Char)": 17611,
    "Sequential Input (Block)": 796,
    "Random Seeks": 20005,
    "Sequential Create": 196000,
    "Random Create": 201000
}

# Latency data for ext4 in microseconds in /shm
ext4_latency_shm = {
    "Per Char": 51865,
    "Block": 34174,
    "Rewrite": 205000,
    "Sequential Input (Per Char)": 17046,
    "Sequential Input (Block)": 1049,
    "Random Seeks": 27760,
    "Sequential Create": 545000,
    "Random Create": 192000
}

# Latency data for XFS in microseconds in /shm
xfs_latency_shm = {
    "Per Char": 32883,
    "Block": 91035,
    "Rewrite": 225000,
    "Sequential Input (Per Char)": 19006,
    "Sequential Input (Block)": 1720,
    "Random Seeks": 117000,
    "Sequential Create": 264000,
    "Random Create": 29618
}

# Set up the figure and axis
fig, axs = plt.subplots(1, 2, figsize=(16, 6), sharey=True)

# Plot Ext4 latency comparison between /mnt and /dev/shm
for ax, fs_latency_mnt, fs_latency_shm, fs_name in zip(axs, [ext4_latency_mnt, xfs_latency_mnt], [ext4_latency_shm, xfs_latency_shm], ['Ext4', 'XFS']):
    latencies_mnt = [fs_latency_mnt[op] for op in operations]
    latencies_shm = [fs_latency_shm[op] for op in operations]
    ax.plot(operations, latencies_mnt, marker='o', label=f'{fs_name} - /mnt')
    ax.plot(operations, latencies_shm, marker='o', label=f'{fs_name} - /dev/shm')

    # Set labels and title for each subplot
    ax.set_ylabel('Latency (microseconds)')
    ax.set_title(f'Latency Comparison for {fs_name}')
    ax.legend()

# Rotate x-axis labels for better visibility
for ax in axs:
    ax.tick_params(axis='x', rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Définir les chansons avec leurs valeurs d'émotion et de gestes des mains
songs = {
    "Chanson 1": {"emotion": 90, "hand_gesture": 80},
    "Chanson 2": {"emotion": 70, "hand_gesture": 50},
    "Chanson 3": {"emotion": 50, "hand_gesture": 30},
    # Ajoutez les autres chansons avec leurs valeurs ici
}

# Afficher une grille de chansons avec leurs valeurs d'émotion et de gestes des mains
print("Liste des chansons:")
print("{:<15} {:<15} {:<15}".format("Chanson", "Emotion (%)", "Hand Gesture (%)"))
for song, values in songs.items():
    print("{:<15} {:<15} {:<15}".format(song, values["emotion"], values["hand_gesture"]))
print("")

# Fonction pour choisir une chanson en fonction des entrées utilisateur
def choose_song(emotion_percent, hand_gesture_percent):
    # Pour l'exemple, choisissez simplement la première chanson
    return "Chanson 1"

# Fonction pour jouer la chanson sélectionnée
def play_song(song_name):
    print("Playing", song_name)

# Interface utilisateur simple
while True:
    try:
        emotion_percent = float(input("Entrez le pourcentage d'émotion (0-100): "))
        hand_gesture_percent = float(input("Entrez le pourcentage de gestes des mains (0-100): "))

        if 0 <= emotion_percent <= 100 and 0 <= hand_gesture_percent <= 100:
            chosen_song = choose_song(emotion_percent, hand_gesture_percent)
            play_song(chosen_song)
        else:
            print("Les pourcentages doivent être compris entre 0 et 100.")
    except ValueError:
        print("Veuillez entrer des nombres valides.")
# Out:
# Liste des chansons:
# Chanson         Emotion (%)     Hand Gesture (%)
# Chanson 1       90              80
# Chanson 2       70              50
# Chanson 3       50              30
# Playing Chanson 1
# Playing Chanson 1
# Veuillez entrer des nombres valides.
# Veuillez entrer des nombres valides.
# Veuillez entrer des nombres valides.
# Veuillez entrer des nombres valides.
# Playing Chanson 1
# Veuillez entrer des nombres valides.
# Veuillez entrer des nombres valides.
# Veuillez entrer des nombres valides.
# Veuillez entrer des nombres valides.
# Veuillez entrer des nombres valides.
# Veuillez entrer des nombres valides.
# Veuillez entrer des nombres valides.
# Veuillez entrer des nombres valides.
# Veuillez entrer des nombres valides.
# Veuillez entrer des nombres valides.
# Veuillez entrer des nombres valides.
# Veuillez entrer des nombres valides.
# Veuillez entrer des nombres valides.
# Veuillez entrer des nombres valides.
# Veuillez entrer des nombres valides.
# ...
